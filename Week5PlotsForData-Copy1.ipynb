# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import requests

# %%
data = pd.read_csv(r'C:\Users\prana\Downloads\Week5Data.csv')

# %%
display(data)
# Out:
#              Time  Temperature (C)  Gas (ohms)  Humidity (%)  Pressure (hPa)  \
# 0    1.676505e+09        42.818281       26984      2.468837     1011.101342
# 1    1.676505e+09        42.832539       36850      2.431234     1011.097013
# 2    1.676505e+09        42.849922       44127      2.393670     1011.083191
# 3    1.676505e+09        42.873164       49568      2.379735     1011.076949
# 4    1.676505e+09        42.896992       53701      2.361090     1011.075269
# ..            ...              ...         ...           ...             ...
# 248  1.676505e+09        44.928242      148810      1.806161     1011.137275
# 249  1.676505e+09        44.923750      148286      1.815575     1011.133729
# 250  1.676505e+09        44.921211      148417      1.810835     1011.136943
# 251  1.676505e+09        44.915547      148417      1.801353     1011.136979
# 252  1.676505e+09        44.914961      148678      1.806070     1011.137861
#
# ...

# %%
display(data["Time"])
# Out:
# 0      1.676505e+09
# 1      1.676505e+09
# 2      1.676505e+09
# 3      1.676505e+09
# 4      1.676505e+09
#            ...
# 248    1.676505e+09
# 249    1.676505e+09
# 250    1.676505e+09
# 251    1.676505e+09
# 252    1.676505e+09
# Name: Time, Length: 253, dtype: float64

# %%
plt.plot(data["Time"], data["Temperature (C)"])
plt.xlabel('Time')
plt.ylabel('Temperature (C)')
plt.title("Temperature vs Time")
plt.show()

# %%
plt.plot(data["Time"], data["Gas (ohms)"])
plt.xlabel('Time')
plt.ylabel('Gas (ohms)')
plt.title("Gas vs Time")
plt.show()

# %%
plt.plot(data["Time"], data["Humidity (%)"])
plt.xlabel('Time')
plt.ylabel('Humidity (%)')
plt.title("Humidity vs Time")
plt.show()

# %%
plt.plot(data["Time"], data["Pressure (hPa)"])
plt.xlabel('Time')
plt.ylabel('Pressure (hPa)')
plt.title("Pressure vs Time")
plt.show()

# %%
plt.plot(data["Time"], data["Altitude (m)"])
plt.xlabel('Time')
plt.ylabel('Altitude (m)')
plt.title("Altitude vs Time")
plt.show()

# %%
# the PM sensors worked when running the code, however the particles picked up were consistenly well before 1 micrometer in size, thus were not picked in the concentration report
plt.plot(data["Time"], data["PM10 Standard (mirogram/m^3)"])
plt.xlabel('Time')
plt.ylabel('PM10 Standard (mirogram/m^3)')
plt.title("PM10 Standard vs Time")
plt.show()

# %%
plt.plot(data["Time"], data["PM25 Standard (mirogram/m^3)"])
plt.xlabel('Time')
plt.ylabel('PM25 Standard (mirogram/m^3)')
plt.title("PM25 Standard vs Time")
plt.show()

# %%
plt.plot(data["Time"], data["PM100 Standard (mirogram/m^3)"])
plt.xlabel('Time')
plt.ylabel('PM100 Standard (mirogram/m^3)')
plt.title("PM100 Standard vs Time")
plt.show()
